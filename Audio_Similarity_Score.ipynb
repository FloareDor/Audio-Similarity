# %%
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt

import librosa as lr
from scipy import spatial
import difflib

# %%
data_dir = 'E:\CS mini projects\Audio_Classification\Data\Test'
audio_files = glob(data_dir + '/*.wav')
arr = []

# %%
for j in audio_files:
    audio, sfreq = lr.load(j)
    print(j)
    time = np.arange(0, len(audio)) / sfreq
    fig, ax = plt.subplots()
    ax.plot(time, audio)
    ax.set(xlabel = 'Time (s)', ylabel = "Amplitude")
    #print(time, audio)
    arr.append(j)
    arr.append(time)
    arr.append(audio)
# Out:
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like hard h1.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like hard h2.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like hard.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like mid h1.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like mid h2.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like mid.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like soft h1.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like soft h2.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you ever feel like soft.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same hard h1.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same hard h2.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same hard.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same mid h1.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same mid h2.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same mid.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same soft h1.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same soft h2.wav
# E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same soft.wav
# E:\CS mini projects\Audio_Classification\Data\Test\don't ever change your mind hard h1.wav

# %%
path_to_sample = 'E:\CS mini projects\Audio_Classification\Data\Test\do you feel the same hard.wav'
n = arr.index(path_to_sample)
print(n)
st = arr[n+1].tolist()
sa = arr[n+2].tolist()
print(len(arr))
for i in range(0,len(arr),3):
    fig, ax = plt.subplots()
    ax.plot(arr[i+1], arr[i+2])
    ax.set(xlabel = 'Time (s)', ylabel = "Amplitude")
    plt.show()
    tt = arr[i+1]
    ta = arr[i+2]
    rt = difflib.SequenceMatcher(None, st, tt)
    ra = difflib.SequenceMatcher(None, sa, ta)
    score = (rt.ratio() + ra.ratio())/2
    print(f"Score: {score}")
    if i == len(arr) - 1:
        break
    
    






#sm=difflib.SequenceMatcher(None,s1,s2)
#print(sm.ratio())
#print(dataSetI)

#result = 1 - spatial.distance.cosine(dataSetI, dataSetII)
#print(result)
# Out:
# 33
# 57
# <ipython-input-70-1a050c7a6d8a>:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   n = arr.index(path_to_sample)
# Score: 0.4638962066516215
# Score: 0.4776691478724586
# Score: 0.4491503290733712
# Score: 0.45596267034307225
# Score: 0.47109528375108434
# Score: 0.44477779214621316
# Score: 0.4604215749268223
# Score: 0.47032388036572137
# Score: 0.4593263948860854
# Score: 0.5000242292670162
# Score: 0.48528839534257234
# Score: 1.0
# Score: 0.4989218485925753
# Score: 0.4769962285575246
# Score: 0.49351019125790363
# Score: 0.4882239948524333
# Score: 0.4876144693192428
# Score: 0.49716697502312673
# Score: 0.4967122681017801

# %%
# Out:
# [array([0.00000000e+00, 4.53514739e-05, 9.07029478e-05, ...,
#        4.73514739e-01, 4.73560091e-01, 4.73605442e-01]), array([-5.3106429e-04, -5.9797661e-04, -2.3602853e-03, ...,
#         7.4346848e-05,  8.8771136e-05,  0.0000000e+00], dtype=float32), array([0.00000000e+00, 4.53514739e-05, 9.07029478e-05, ...,
#        8.79319728e-01, 8.79365079e-01, 8.79410431e-01]), array([ 3.8399844e-06,  4.7619596e-05,  9.6240932e-05, ...,
#        -6.4745860e-04, -6.5556250e-04, -6.7860488e-04], dtype=float32), array([0.00000000e+00, 4.53514739e-05, 9.07029478e-05, ...,
#        3.32199546e-01, 3.32244898e-01, 3.32290249e-01]), array([-1.3632159e-04,  2.2759419e-05, -4.1025924e-04, ...,
#         1.5014244e-03,  1.4733518e-03,  1.5856171e-03], dtype=float32)]
